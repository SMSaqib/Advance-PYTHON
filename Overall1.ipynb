# %% [markdown]
# Lists:
#
# Creation of lists and basic operations.
# Iteration through lists using for loops.
# Adding, modifying, and deleting elements from a list.
# Slicing lists to extract specific elements.
# Tuples:
#
# Creation of tuples.
# Accessing tuple elements.
# Reassigning a tuple (since tuples are immutable).
# Dictionaries:
#
# Creation of dictionaries.
# Accessing, adding, modifying, and deleting key-value pairs.
# Iterating through dictionary keys, values, and key-value pairs.
# Nested dictionaries (dictionaries within dictionaries).
#
# Loops:
# Using for loops to iterate through lists, dictionaries, and other sequences.
# Iterating with enumerate to get both the index and value.
# Using while loops for repetitive tasks.
# Exiting loops using break.
# Skipping iterations using continue.
#
# Range:
# Generating sequences of numbers using the range function.
#
# List Comprehensions:
# Creating new lists based on existing lists with concise syntax.
#
# Nesting:
# Lists of dictionaries and dictionaries within dictionaries.
#
# User Input:
# Collecting and validating user input.
#
# Error Handling:
# Handling errors and avoiding infinite loops
#
# ![image.png](attachment:image.png)
#
#
# Differnce of tuple list and dictionary
#
# ![image-2.png](attachment:image-2.png)
#
#
# For and while Loop:
#
# ![image-3.png](attachment:image-3.png)

# %%
# List
# * Iteration operation with a loop
# * Apply any operation on elements

names: list[str] = ['Sir Zia', "Muhammad Qasim", "DR Noman"]
print(names)

for name in names:
    print(name)

# Looping through a list
for name in names:
    print(f'Welcome Dear Teacher {name.title()}')

# Adding a new line after each teacher's welcome message
for name in names:
    print(f'Welcome Dear Teacher {name.title()}')
    print("PIAIC Gen AI Team\n")

print("Pakistan zinda bad")

# Reversing the list and converting names to uppercase
for name in names[::-1]:
    print(f'Welcome Dear Teacher {name.upper()}')
    print("PIAIC Gen AI Team\n")
print("Pakistan zinda bad\n")

# Iterating through a list of tuples
data_base: list[tuple[str, str]] = [("qasim", '123'),
                                    ("sirzia", '345'),
                                    ('ikhlas', '789')]

for row in data_base:
    print(row)

# Unpacking tuple elements
for row in data_base:
    user, password = row
    print(user, password)

# Basic user input and validation
input_user: str = input("Enter user name")
input_password: str = input("Enter user password")
print(input_user , input_password )
for row in data_base:
    user, password = row
    if input_user == user and input_password == password:
        print(f"Valid User {user}")
        break
else:
    print("Not found or Invalid user name")

# Iterating through a list with the else block
names: list[str] = ['Sir Zia', "Muhammad Qasim", "DR Noman"]

for name in names:
    print(name)
else:
    print("Hello world")

# Using the break statement to exit the loop
for name in names:
    print(name)
    break
else:
    print("Hello world")

# Without using the else block
for name in names:
    print(name)
print("Hello world")

# Printing without the break statement
for name in names:
    print(name)
    break
print("Hello world")

# Code blocks without proper indentation
names: list[str] = ['Sir Zia', "Muhammad Qasim", "DR Noman"]

for name in names:
print(name)

# Missing a colon
for name in names
    print(name)

# Using a list and a for loop to greet magicians
magicians: list[str] = ['alice', 'david', 'carolina']

for magician in magicians:
    print(f"{magician.title()}, that was a great trick!")

# String indentation error
message = "Hello Python world!"
    print(message)

# Corrected code
message = "Hello Python world!"
print(message)

# Using a for loop and slicing to greet magicians
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
    print(f"{magician.title()}, that was a great trick!")
    print(f"I can't wait to see your next trick, {magician.title()}.\n")

print("Thank you, everyone; that was a great magic show!")

# Using the enumerate function
magicians = ['alice', 'david', 'carolina']
for index, name in enumerate(magicians):
    print(index, name)

# Numbers with a loop
# * `range(start, end, step)`

range(10)
list(range(10))

# Using a range with a start and end value
list(range(2, 10))

# Using a range with a start, end, and step value
list(range(2, 21, 2))

# Multiplication table with a for loop
for n in range(1, 11):
    print(n)

for n in range(1, 11):
    print(f"{2} X {n} = {n * 2}")

# Using a for loop to generate a list of squares
squares: list[int] = []
for value in range(1, 11):
    square = value ** 2
    squares.append(square)

print(squares)

# Using a list comprehension to generate a list of squares
squares = [i ** 2 for i in range(1, 11)]

# List comprehension
[i ** 2 for i in range(1, 11)]

# Using the range function to create a list
list(range(1, 11))

# Using a for loop to print square values
for i in range(1, 11):
    print(i ** 2)

# Missing indentations
'line1'
'line2'
'line3'  # Always returns the last line

# Printing lines with proper indentation
print('line1')
print('line2')
print('line3')  # Always returns the last line

# Using a list comprehension to generate square values
[i ** 2 for i in range(1, 11)]

# Sum, max, and min of a list
digits: list[int] = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

print(digits)
print(max(digits))
print(min(digits))
print(sum(digits))

# Copying a list
my_foods = ['pizza', 'falafel', 'carrot cake']
friend_foods = my_foods[:]
print(my_foods)
print(friend_foods)
friend_foods[0] = "Tikka"
print(my_foods)
print(friend_foods)

# Tuples
names: tuple[str] = ('A', "B", 'C')
print(names[0])
print(names[0:2])

# Attempt to modify a tuple (Will result in an error)
names[0] = "Pakistan"

# Reassigning a tuple
names = ('Pakistan', "B", 'C')
print(names)
from typing import List, Tuple, Dict, Union

# Creating a dictionary
alien_0: dict[str, Union[str, int]] = {
    'color': 'green',
    'points': 42
}

# Accessing a dictionary
print(alien_0['color'])
print(alien_0['points'])

# # Adding new key-value pairs to a dictionary
# alien_0 = {
#     'color': 'green',
#     'points': 5
# }

alien_0['x_position'] = 0
alien_0['y_position'] = 25

print(alien_0)

# Modifying values in a dictionary
alien_0 = {
    'color': 'blue',
    'points': 5
}

print(f"The alien is {alien_0['color']}.")

alien_0['color'] = 'yellow'
print(f"The alien is now {alien_0['color']}.")

# Removing key-value pairs
alien_0 = {
    'color': 'green',
    'points': 5
}

print(alien_0)

del alien_0['points']
print(alien_0)

# Using a dictionary to store user information
user_0: dict[str, Union[str, int]] = {
    'username': 'efermi',
    'first': 'enrico',
    'last': 'fermi',
    "Password":"fdsfsfs",
}
print([i for i in dir(user_0) if "__" not in i]) # methods and attributes

for key, value in user_0.items():
    print(f"\nKey: {key}")
    print(f"Value: {value}")

# Looping through all the keys in a dictionary
for key in user_0.keys():
    print(key)

# Looping through all the values in a dictionary
for value in user_0.values():
    print(value)

# Nesting
# A List of Dictionaries
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}

aliens: list[dict[str, Union[str, int]]] = [alien_0, alien_1, alien_2]

for alien in aliens:
    print(alien)

# More complex example
aliens = []
import random
# Create 30 green aliens
for alien_number in range(1,21):
    colors=["red","green","blue","white","indigo","purple","Amber"]
    Points=[i for i in range(1,100,7)]
    Speed=["slow","Medium","Fast"]

    new_alien = {'color': random.choice(colors), 'points': random.choice(Points), 'speed': random.choice(Speed)}
    aliens.append(new_alien)
    # print(new_alien)
# Show the first 5 aliens
for alien in aliens[:5]:
    print(alien)
print("...")

# Show how many aliens have been created
print(f"Total number of aliens: {len(aliens[0]['speed'])}")

Changing values in a list of dictionaries
Create an empty list for storing aliens.
aliens = []

# Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

# Change the attributes of the first three aliens.
for alien in aliens[:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['points'] = 10
        alien['speed'] = 'medium'

# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)
print("...")

# Show how many aliens have been created.
print(f"Total number of aliens: {len(aliens)}")

A list in a dictionary
pizza: dict[List[str], Union[str, List[str]]] = {
    'crust': ['thick',"thin","filled"],
    'toppings': ['mushrooms', 'extra cheese'],
}

# Summarize the order.
print(f"You ordered a {pizza['crust']}-crust pizza "
      "with the following toppings:")

for topping in pizza['toppings']:
    print("\t" + topping)

Nested dictionaries
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton',
    },
    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris',
    },
}

for username, user_info in users.items():
    print(f"\nUsername: {username}")
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']
    print(full_name ,location )
    print(f"\tFull name: {full_name.title()}")
    print(f"\tLocation: {location.title()}")

# Using a while loop to count to 5
current_number = 1
while current_number <= 5:
    print(current_number)
    current_number += 1

# Letting the user choose when to quit
prompt = "\nTell me something, and I will repeat it back to you:"
prompt += "\nEnter 'quit' to end the program. "

message = ""
while message != 'quit':
    message = input(prompt)
    if message != 'quit':
        print(message)

# Using a flag
prompt = "\nTell me something, and I will repeat it back to you:"
prompt += "\nEnter 'quit' to end the program. "

active = True
while active:
    message = input(prompt)

    if message == 'quit':
        active = False
    else:
        print(message)

# Using break to exit a loop
prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\n(Enter 'quit' when you are finished.) "

while True:
    city = input(prompt)

    if city == 'quit':
        break
    else:
        print(f"I'd love to go to {city.title()}!")

# Using continue in a loop
current_number = 0
while current_number < 10:
    current_number += 1
    if current_number % 2 == 0:
        continue

    print(current_number)

# Avoiding infinite loops
x = 1
while x <= 5:
    print(x)
     x += 1
# Out:
#   Cell In[1], line 83
#     print(name)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 82
